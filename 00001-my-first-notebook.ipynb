# %% [markdown]
# <a href="https://www.kaggle.com/code/macazaka/00001-my-first-notebook-print-hello-world?scriptVersionId=91986815" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Python Prelims

# %%
#Code box
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# Raw Text or Markdown box
