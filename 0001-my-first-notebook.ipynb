# %% [markdown]
# <a href="https://www.kaggle.com/code/macazaka/0001-my-first-notebook?scriptVersionId=91976721" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Python Prelims

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# Raw Text
