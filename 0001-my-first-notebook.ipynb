# %% [markdown]
# <a href="https://www.kaggle.com/code/macazaka/00001-my-first-notebook-print-hello-world?scriptVersionId=91981703" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Python Prelims

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# Raw Text
